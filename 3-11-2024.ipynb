# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
data = fetch_california_housing()
X = data.data
y = data.target
rs = 42

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = rs)

print(np.count_nonzero(np.isnan(X_train)))
print(np.count_nonzero(np.isnan(y_train)))
print(np.count_nonzero(np.isnan(X_test)))
print(np.count_nonzero(np.isnan(y_test)))
# Out:
# 0
# 0
# 0
# 0

# %%
plt.plot(y_train, X_train)
plt.show()

# %%
plt.plot(y_test, X_test)
plt.show()

# %%
lm = LinearRegression()
train_set = lm.fit(X_train, y_train)
test_set = lm.fit(X_test, y_test)

# %%
k = KFold(n_splits = 5)

scorestn = cross_val_score(train_set, x_train, y_train, cv = k)
scorestt = cross_val_score(test_set, x_test, y_test, cv = k)

# %%
scorestn
# Out:
# array([0.62011512, 0.61298876, 0.6134416 , 0.61069973, 0.60017477])

# %%
scorestt
# Out:
# array([0.61842364, 0.53314848, 0.59393102, 0.56612423, 0.5364846 ])
